# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
pwd
# Out:
# '/content'

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/TIME_SERIES/daily-total-female-births-CA.csv',header=0)

# %%
df.head()
# Out:
#          date  births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    365 non-null    object
#  1   births  365 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
df2=pd.read_csv('/content/drive/My Drive/Colab Notebooks/TIME_SERIES/daily-total-female-births-CA.csv',header=0,parse_dates=[0])

# %%
df2.head()
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
df2['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
series=pd.read_csv('/content/drive/My Drive/Colab Notebooks/TIME_SERIES/daily-total-female-births-CA.csv',header=0,parse_dates=[0],index_col=0,squeeze=True)

# %%
series.head()
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: births, dtype: int64

# %%
series.shape
# Out:
# (365,)

# %%
df2.shape
# Out:
# (365, 2)

# %%
print(series['1959-01'])
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# 1959-01-11    38
# 1959-01-12    33
# 1959-01-13    55
# 1959-01-14    47
# 1959-01-15    45
# 1959-01-16    37
# 1959-01-17    50
# 1959-01-18    43
# 1959-01-19    41
# 1959-01-20    52
# 1959-01-21    34
# 1959-01-22    53
# 1959-01-23    39
# 1959-01-24    32
# 1959-01-25    37
# 1959-01-26    43
# 1959-01-27    39
# 1959-01-28    35
# 1959-01-29    44
# 1959-01-30    38
# 1959-01-31    24
# Name: births, dtype: int64

# %%
df[(df['date']>'1959-01-01')&(df['date']<'1959-01-21')]
# Out:
#           date  births
# 1   1959-01-02      32
# 2   1959-01-03      30
# 3   1959-01-04      31
# 4   1959-01-05      44
# 5   1959-01-06      29
# 6   1959-01-07      45
# 7   1959-01-08      43
# 8   1959-01-09      38
# 9   1959-01-10      27
# 10  1959-01-11      38
# 11  1959-01-12      33
# 12  1959-01-13      55
# 13  1959-01-14      47
# 14  1959-01-15      45
# 15  1959-01-16      37
# 16  1959-01-17      50
# 17  1959-01-18      43
# 18  1959-01-19      41
# 19  1959-01-20      52

# %%
series.describe()
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: births, dtype: float64

# %%
df2.describe()
# Out:
#            births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %% [markdown]
# # Data Visualisation

# %%
import matplotlib.pyplot as plt

# %%
data_visual = df2.copy()

# %%
data_visual.head(10)
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44
# 5 1959-01-06      29
# 6 1959-01-07      45
# 7 1959-01-08      43
# 8 1959-01-09      38
# 9 1959-01-10      27

# %%
data_visual['births'].plot()

# %%
data_visual.index = data_visual['date']

# %%
data_visual.head(10)
# Out:
#                  date  births
# date
# 1959-01-01 1959-01-01      35
# 1959-01-02 1959-01-02      32
# 1959-01-03 1959-01-03      30
# 1959-01-04 1959-01-04      31
# 1959-01-05 1959-01-05      44
# 1959-01-06 1959-01-06      29
# 1959-01-07 1959-01-07      45
# 1959-01-08 1959-01-08      43
# 1959-01-09 1959-01-09      38
# 1959-01-10 1959-01-10      27

# %%
data_visual['births'].plot()

# %% [markdown]
# # Zooming In

# %%
data_visual2=data_visual[(data_visual['date']>'1959-01-01')&(data_visual['date']<'1959-01-10')].copy()
data_visual2
# Out:
#                  date  births
# date
# 1959-01-02 1959-01-02      32
# 1959-01-03 1959-01-03      30
# 1959-01-04 1959-01-04      31
# 1959-01-05 1959-01-05      44
# 1959-01-06 1959-01-06      29
# 1959-01-07 1959-01-07      45
# 1959-01-08 1959-01-08      43
# 1959-01-09 1959-01-09      38

# %%
data_visual2['births'].plot()

# %% [markdown]
# # Trendline

# %%
import seaborn as sns

# %%
sns.regplot(x=df2.index.values,y=df2['births'])

# %%
sns.regplot(x=df2.index.values,y=df2['births'],order=2)
